# %%
import numpy as np
from PIL import Image
import scipy.misc
#

# %%
img = Image.open('/home/andres/thesis/notebooks/block0.png')
img1 = Image.open('/home/andres/thesis/notebooks/block1.png')

# %%
a = np.asarray(img1)

size_1 = 314
size_2 = 254

for i in range(4):
    block = a[i*size_2:(i+1)*size_2]
    scipy.misc.imsave('block1{}.png'.format(i), block)
# Out:
# /home/andres/.local/lib/python3.6/site-packages/ipykernel_launcher.py:8: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.

# %%
a.shape
# Out:
# (629, 1017, 3)

# %%
block = a[314:628]
block = block

# %%
import matplotlib.pyplot as plt

plt.imshow(block)
